# %%
import json
import os
import urllib

def download_and_load_file(file_path, url):
    if not os.path.exists(file_path):
        with urllib.request.urlopen(url) as response:
            text_data = response.read().decode("utf-8")
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(text_data)
    else:
        with open(file_path, "r", encoding="utf-8") as file:
            text_data = file.read()
    with open(file_path, "r") as file:
        data = json.load(file)
    return data

file_path = "instruction-data.json"
url = (
    "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch"
    "/main/ch07/01_main-chapter-code/instruction-data.json"
)


data = download_and_load_file(file_path, url)
print("Number of entries:", len(data))
# Out:
# Number of entries: 1100

# %%
print("Example entry:\n", data[50])
# Out:
# Example entry:
#  {'instruction': 'Identify the correct spelling of the following word.', 'input': 'Ocassion', 'output': "The correct spelling is 'Occasion.'"}

# %% [markdown]
# prompt formatting function

# %%
def format_input(entry):
    instruction_text = (
        f"Below is an instruction that describe a task. "
        f"Write a response that appropriately completes the request"
        f"\n\n### Instruction:\n{entry['instruction']}"
    )
    
    input_text = (
        f"\n\n### Input:\n{entry['input']}" if entry['input'] else ''
    )
    
    return instruction_text + input_text

# %%
model_input = format_input(data[50])
desired_response = f"\n\n### Response:\n{data[50]['output']}"
print(model_input + desired_response)
# Out:
# Below is an instruction that describe a task. Write a response that appropriately completes the request
#
# ### Instruction:
# Identify the correct spelling of the following word.
#
# ### Input:
# Ocassion
#
# ### Response:
# The correct spelling is 'Occasion.'

# %%
model_input = format_input(data[999])
desired_response = f"\n\n### Response:\n{data[999]['output']}"
print(model_input + desired_response)
# Out:
# Below is an instruction that describe a task. Write a response that appropriately completes the request
#
# ### Instruction:
# What is an antonym of 'complicated'?
#
# ### Response:
# An antonym of 'complicated' is 'simple'.

# %%
train_portion = int(len(data) * 0.85)
test_portion = int(len(data) * 0.1)
val_portion = len(data) - train_portion - test_portion

train_data = data[:train_portion]
test_data = data[train_portion:train_portion + test_portion]
val_data = data[train_portion + test_portion:]

print("Training set length:", len(train_data))
print("Validation set length:", len(val_data))
print("Test set length:", len(test_data))
# Out:
# Training set length: 935
# Validation set length: 55
# Test set length: 110

# %%
# dataset class for the instruction dataset


import torch
from torch.utils.data import Dataset

class InstructionDataset(Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.encoded_texts = []
        for entry in data:
            instruction_plus_input = format_input(entry)
            response_text = f"\n\n### Response:\n{entry['output']}"
            full_text = instruction_plus_input + response_text
            self.encoded_texts.append(
                tokenizer.encode(full_text)
            )

    def __getitem__(self, index):
        return self.encoded_texts[index]

    def __len__(self):
        return len(self.data)

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")
print(tokenizer.encode("<|endoftext|>", allowed_special={"<|endoftext|>"}))
# Out:
# [50256]

# %%
# collate for input tokens

def custom_collate_draft_1(
    batch, 
    pad_token_id=50256,
    device="cpu"
):
    batch_max_length = max(len(item) + 1 for item in batch)
    inputs_lst = []
    
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        
        
        padded = (
            new_item + [pad_token_id] *
            (batch_max_length - len(new_item))
        )
        
        inputs = torch.tensor(padded[:-1])
        inputs_lst.append(inputs)
        
    inputs_tensor = torch.stack(inputs_lst).to(device)
    return inputs_tensor

# %%
inputs_1 = [0, 1, 2, 3, 4]
inputs_2 = [5, 6]
inputs_3 = [7, 8, 9]
batch = (
    inputs_1,
    inputs_2,
    inputs_3
)
print(custom_collate_draft_1(batch))
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])

# %%
# collate for output tokens
def custom_collate_draft_2(
    batch, 
    pad_token_id=50256,
    device="cpu"
):
    batch_max_length = max(len(item) + 1 for item in batch)
    inputs_lst, targets_lst = [], []
    
    
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        
        padded = (
            new_item + [pad_token_id] * 
            (batch_max_length - len(new_item))
        )
        inputs = torch.tensor(padded[:-1])
        targets = torch.tensor(padded[1:])
        inputs_lst.append(inputs)
        targets_lst.append(targets)
        
        
    inputs_tensor = torch.stack(inputs_lst).to(device)
    targets_tensor = torch.stack(targets_lst).to(device)
    return inputs_tensor, targets_tensor




inputs, targets = custom_collate_draft_2(batch)
print(inputs)
print(targets)
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])
# tensor([[    1,     2,     3,     4, 50256],
#         [    6, 50256, 50256, 50256, 50256],
#         [    8,     9, 50256, 50256, 50256]])

# %% [markdown]
# combining both draft of input and output in one collate function

# %%
def custom_collate_fn(
    batch, 
    pad_token_id=50256,
    ignore_index=-100,
    allowed_max_length=None,
    device="cpu"
):
    batch_max_length = max(len(item) + 1 for item in batch)
    inputs_lst, targets_lst = [], []
    
    
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        
        padded = (
            new_item + [pad_token_id] * 
            (batch_max_length - len(new_item))
        )
        
        inputs = torch.tensor(padded[:-1])
        targets = torch.tensor(padded[1:])
        
        
        mask = targets == pad_token_id
        indices = torch.nonzero(mask).squeeze()
        
        if indices.numel() > 1:
            targets[indices[1:]] = ignore_index
            
            
        if allowed_max_length is not None:
            inputs = inputs[:allowed_max_length]
            targets = targets[:allowed_max_length]
            
            
        inputs_lst.append(inputs)
        targets_lst.append(targets)
        
        
    inputs_tensor = torch.stack(inputs_lst).to(device)
    targets_tensor = torch.stack(targets_lst).to(device)
    return inputs_tensor, targets_tensor

# %%
# trying collate function
inputs, targets = custom_collate_fn(batch)
print(inputs)
print(targets)
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])
# tensor([[    1,     2,     3,     4, 50256],
#         [    6, 50256,  -100,  -100,  -100],
#         [    8,     9, 50256,  -100,  -100]])

# %%
logits_1 = torch.tensor(
    [[-1.0, 1.0],
     [-0.5, 1.5]]
)
targets_1 = torch.tensor([0, 1]) # Correct token indices to generate
loss_1 = torch.nn.functional.cross_entropy(logits_1, targets_1)
print(loss_1)
# Out:
# tensor(1.1269)

# %%
logits_2 = torch.tensor(
    [[-1.0, 1.0],
     [-0.5, 1.5],
     [-0.5, 1.5]]
)
targets_2 = torch.tensor([0, 1, 1])
loss_2 = torch.nn.functional.cross_entropy(logits_2, targets_2)
print(loss_2)
# Out:
# tensor(0.7936)

# %%
# how -100 remove the affect of that value. This is internally in the pytorch softmax

targets_3 = torch.tensor([0, 1, -100])
loss_3 = torch.nn.functional.cross_entropy(logits_2, targets_3)
print(loss_3)
print("loss_1 == loss_3:", loss_1 == loss_3)
# Out:
# tensor(1.1269)
# loss_1 == loss_3: tensor(True)

# %%
device =device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

print("Device: ", device)
# Out:
# Device:  cpu

# %%
from functools import partial

customized_collate_fun = partial(
    custom_collate_fn, 
    device=device,
    allowed_max_length=1024
)

# %%
from torch.utils.data import DataLoader


num_workers = 0
batch_size = 2


torch.manual_seed(123)


train_dataset = InstructionDataset(train_data, tokenizer)


train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fun, 
    shuffle=True,
    drop_last=True,
    num_workers=num_workers
)


val_dataset = InstructionDataset(val_data, tokenizer)
val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fun,
    shuffle=False,
    drop_last=False,
    num_workers=num_workers
)


test_dataset = InstructionDataset(test_data, tokenizer)
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fun,
    shuffle=False,
    drop_last=False,
    num_workers=num_workers
)

# %%
print("Train Loader: ")
for inputs, targets in train_loader:
    print(inputs.shape, targets.shape)
# Out:
# Train Loader:
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 46]) torch.Size([2, 46])
# torch.Size([2, 75]) torch.Size([2, 75])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 72]) torch.Size([2, 72])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 71]) torch.Size([2, 71])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 79]) torch.Size([2, 79])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 74]) torch.Size([2, 74])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 48]) torch.Size([2, 48])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 76]) torch.Size([2, 76])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 78]) torch.Size([2, 78])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 79]) torch.Size([2, 79])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 47]) torch.Size([2, 47])
# torch.Size([2, 47]) torch.Size([2, 47])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 75]) torch.Size([2, 75])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 47]) torch.Size([2, 47])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 90]) torch.Size([2, 90])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 45]) torch.Size([2, 45])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 48]) torch.Size([2, 48])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 74]) torch.Size([2, 74])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 88]) torch.Size([2, 88])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 87]) torch.Size([2, 87])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 73]) torch.Size([2, 73])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 75]) torch.Size([2, 75])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 74]) torch.Size([2, 74])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 74]) torch.Size([2, 74])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 73]) torch.Size([2, 73])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 79]) torch.Size([2, 79])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 86]) torch.Size([2, 86])
# torch.Size([2, 71]) torch.Size([2, 71])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 48]) torch.Size([2, 48])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 46]) torch.Size([2, 46])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 45]) torch.Size([2, 45])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 71]) torch.Size([2, 71])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 53]) torch.Size([2, 53])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 71]) torch.Size([2, 71])
# torch.Size([2, 45]) torch.Size([2, 45])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 73]) torch.Size([2, 73])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 72]) torch.Size([2, 72])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 79]) torch.Size([2, 79])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 69]) torch.Size([2, 69])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 90]) torch.Size([2, 90])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 70]) torch.Size([2, 70])
# torch.Size([2, 79]) torch.Size([2, 79])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 80]) torch.Size([2, 80])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 73]) torch.Size([2, 73])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 48]) torch.Size([2, 48])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 81]) torch.Size([2, 81])
# torch.Size([2, 76]) torch.Size([2, 76])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 45]) torch.Size([2, 45])
# torch.Size([2, 67]) torch.Size([2, 67])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 62]) torch.Size([2, 62])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 76]) torch.Size([2, 76])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 90]) torch.Size([2, 90])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 61]) torch.Size([2, 61])
# torch.Size([2, 74]) torch.Size([2, 74])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 48]) torch.Size([2, 48])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 49]) torch.Size([2, 49])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 66]) torch.Size([2, 66])
# torch.Size([2, 77]) torch.Size([2, 77])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 75]) torch.Size([2, 75])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 50]) torch.Size([2, 50])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 54]) torch.Size([2, 54])
# torch.Size([2, 82]) torch.Size([2, 82])
# torch.Size([2, 52]) torch.Size([2, 52])
# torch.Size([2, 58]) torch.Size([2, 58])
# torch.Size([2, 65]) torch.Size([2, 65])
# torch.Size([2, 51]) torch.Size([2, 51])
# torch.Size([2, 57]) torch.Size([2, 57])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 64]) torch.Size([2, 64])
# torch.Size([2, 72]) torch.Size([2, 72])
# torch.Size([2, 73]) torch.Size([2, 73])
# torch.Size([2, 56]) torch.Size([2, 56])
# torch.Size([2, 59]) torch.Size([2, 59])
# torch.Size([2, 55]) torch.Size([2, 55])
# torch.Size([2, 68]) torch.Size([2, 68])
# torch.Size([2, 60]) torch.Size([2, 60])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 63]) torch.Size([2, 63])
# torch.Size([2, 71]) torch.Size([2, 71])

# %%
#loading pretrained LLM



import urllib.request
import zipfile
import os
from pathlib import Path

url = "https://archive.ics.uci.edu/static/public/228/sms+spam+collection.zip"
zip_path = "sms_spam_collection.zip"
extracted_path = "sms_spam_collection"
data_file_path = Path(extracted_path) / "SMSSpamCollection.tsv"


def download_and_unzip_spam_data(
        url, zip_path, extracted_path, data_file_path):
    if data_file_path.exists():
        print(f"{data_file_path} already exists. Skipping download "
              "and extraction."
        )
        return

    with urllib.request.urlopen(url) as response:
        with open(zip_path, "wb") as out_file:
            out_file.write(response.read())

    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(extracted_path)

    original_file_path = Path(extracted_path) / "SMSSpamCollection"
    os.rename(original_file_path, data_file_path)
    print(f"File downloaded and saved as {data_file_path}")

download_and_unzip_spam_data(url, zip_path, extracted_path, data_file_path)




#Multi Head Attention with Weight Splits
import torch
from torch import nn



class GELU(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
    

class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))
        
    def forward(self, x):
        mean = x.mean(dim = -1, keepdim = True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean ) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift
    
    
class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, 
                 context_length, dropout, num_heads, qkv_bias=False):
        
        super().__init__()
        assert( d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"
            
        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads
        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length), 
                       diagonal=1)
        )
        
    def forward(self, x):
        b, num_tokens, d_in = x.shape
        keys = self.W_key(x)
        queries = self.W_query(x)
        values = self.W_value(x)
        
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)
        
        
        attn_scores = queries @ keys.transpose(2, 3)
        mask_book = self.mask.bool()[:num_tokens, :num_tokens]
        
        attn_scores.masked_fill_(mask_book, -torch.inf)
        
        attn_weights = torch.softmax(
            attn_scores/ keys.shape[-1] ** -.5, dim=-1
        )
        attn_weights = self.dropout(attn_weights)
        
        context_vec = (attn_weights @ values).transpose(1, 2)
        
        context_vec = context_vec.contiguous().view(
            b, num_tokens, self.d_out
        )
        
        context_vec = self.out_proj(context_vec)
        return context_vec
        


class FeedFoward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers  = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), GELU(),
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]),
        )
        
    def forward(self, x):
        return self.layers(x)
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in = cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"]
        )
        self.ff = FeedFoward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])
        
        
    def forward(self, x):
        
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)
        x = self.drop_shortcut(x)
        x = x + shortcut
        
        
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)
        x = x + shortcut
        
        return x
    
    

class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])
        
        self.trf_blocks = nn.Sequential(*[
            TransformerBlock(cfg) for _ in range(cfg["n_layers"])
        ])
        
        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )
        
        
    def forward(self, in_idx):
        
        batch_size , seq_len = in_idx.shape
        
        tok_embeds = self.tok_emb(in_idx)
        
        pos_embeds = self.pos_emb(
            torch.arange(seq_len, device=in_idx.device)
        )
        
        x = tok_embeds + pos_embeds
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits
        


def assign(left, right):
    if left.shape != right.shape:
        raise ValueError(f"Shape mismatch. Left: {left.shape}, "
                          "Right: {right.shape}"
        )
    return torch.nn.Parameter(torch.tensor(right))


import numpy as np

def load_weights_into_gpt(gpt, params):
    gpt.pos_emb.weight = assign(gpt.pos_emb.weight, params['wpe'])
    gpt.tok_emb.weight = assign(gpt.tok_emb.weight, params['wte'])

    for b in range(len(params["blocks"])):
        q_w, k_w, v_w = np.split(
            (params["blocks"][b]["attn"]["c_attn"])["w"], 3, axis=-1)
        gpt.trf_blocks[b].att.W_query.weight = assign(
            gpt.trf_blocks[b].att.W_query.weight, q_w.T)
        gpt.trf_blocks[b].att.W_key.weight = assign(
            gpt.trf_blocks[b].att.W_key.weight, k_w.T)
        gpt.trf_blocks[b].att.W_value.weight = assign(
            gpt.trf_blocks[b].att.W_value.weight, v_w.T)

        q_b, k_b, v_b = np.split(
            (params["blocks"][b]["attn"]["c_attn"])["b"], 3, axis=-1)
        gpt.trf_blocks[b].att.W_query.bias = assign(
            gpt.trf_blocks[b].att.W_query.bias, q_b)
        gpt.trf_blocks[b].att.W_key.bias = assign(
            gpt.trf_blocks[b].att.W_key.bias, k_b)
        gpt.trf_blocks[b].att.W_value.bias = assign(
            gpt.trf_blocks[b].att.W_value.bias, v_b)

        gpt.trf_blocks[b].att.out_proj.weight = assign(
            gpt.trf_blocks[b].att.out_proj.weight, 
            params["blocks"][b]["attn"]["c_proj"]["w"].T)
        gpt.trf_blocks[b].att.out_proj.bias = assign(
            gpt.trf_blocks[b].att.out_proj.bias, 
            params["blocks"][b]["attn"]["c_proj"]["b"])

        gpt.trf_blocks[b].ff.layers[0].weight = assign(
            gpt.trf_blocks[b].ff.layers[0].weight, 
            params["blocks"][b]["mlp"]["c_fc"]["w"].T)
        gpt.trf_blocks[b].ff.layers[0].bias = assign(
            gpt.trf_blocks[b].ff.layers[0].bias, 
            params["blocks"][b]["mlp"]["c_fc"]["b"])
        gpt.trf_blocks[b].ff.layers[2].weight = assign(
            gpt.trf_blocks[b].ff.layers[2].weight, 
            params["blocks"][b]["mlp"]["c_proj"]["w"].T)
        gpt.trf_blocks[b].ff.layers[2].bias = assign(
            gpt.trf_blocks[b].ff.layers[2].bias, 
            params["blocks"][b]["mlp"]["c_proj"]["b"])

        gpt.trf_blocks[b].norm1.scale = assign(
            gpt.trf_blocks[b].norm1.scale, 
            params["blocks"][b]["ln_1"]["g"])
        gpt.trf_blocks[b].norm1.shift = assign(
            gpt.trf_blocks[b].norm1.shift, 
            params["blocks"][b]["ln_1"]["b"])
        gpt.trf_blocks[b].norm2.scale = assign(
            gpt.trf_blocks[b].norm2.scale, 
            params["blocks"][b]["ln_2"]["g"])
        gpt.trf_blocks[b].norm2.shift = assign(
            gpt.trf_blocks[b].norm2.shift, 
            params["blocks"][b]["ln_2"]["b"])


    ## TODO: WHY final_norm?
    gpt.final_norm.scale = assign(gpt.final_norm.scale, params["g"])
    gpt.final_norm.shift = assign(gpt.final_norm.shift, params["b"])
    gpt.out_head.weight = assign(gpt.out_head.weight, params["wte"])
# Out:
# sms_spam_collection/SMSSpamCollection.tsv already exists. Skipping download and extraction.

# %%
from gpt_download import download_and_load_gpt2

BASE_CONFIG = {
    "vocab_size": 50257,     # Vocabulary size
    "context_length": 1024,  # Context length
    "drop_rate": 0.0,        # Dropout rate
    "qkv_bias": True         # Query-key-value bias
}

model_configs = {
    "gpt2-small (124M)": {"emb_dim": 768, "n_layers": 12, "n_heads": 12},
    "gpt2-medium (355M)": {"emb_dim": 1024, "n_layers": 24, "n_heads": 16},
    "gpt2-large (774M)": {"emb_dim": 1280, "n_layers": 36, "n_heads": 20},
    "gpt2-xl (1558M)": {"emb_dim": 1600, "n_layers": 48, "n_heads": 25},
}

CHOOSE_MODEL = "gpt2-medium (355M)"
BASE_CONFIG.update(model_configs[CHOOSE_MODEL])

model_size = CHOOSE_MODEL.split(" ")[-1].lstrip("(").rstrip(")")

settings, params = download_and_load_gpt2(
    model_size=model_size, 
    models_dir="gpt2"
)

model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.eval();
# Out:
# File already exists and is up-to-date: gpt2/355M/checkpoint
# File already exists and is up-to-date: gpt2/355M/encoder.json
# File already exists and is up-to-date: gpt2/355M/hparams.json
# File already exists and is up-to-date: gpt2/355M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2/355M/model.ckpt.index
# File already exists and is up-to-date: gpt2/355M/model.ckpt.meta
# File already exists and is up-to-date: gpt2/355M/vocab.bpe

# %%
torch.manual_seed(123)
input_text = format_input(val_data[0])
print(input_text)
# Out:
# Below is an instruction that describe a task. Write a response that appropriately completes the request
#
# ### Instruction:
# Convert the active sentence to passive: 'The chef cooks the meal every day.'

# %%
import math
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)
    return tokenizer.decode(flat.tolist())


def generate(model, idx, max_new_tokens, context_size,
             temperature=0.0, top_k=None, eos_id=None):
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]
        if top_k is not None:
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(
                logits < min_val,
                torch.tensor(float('-inf')).to(logits.device),
                logits
            )
        if temperature > 0.0:
            logits = logits / temperature
            probs = torch.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)
        if idx_next == eos_id:
            break
        idx = torch.cat((idx, idx_next), dim=1)
    return idx

# %%
token_ids = generate(
    model=model,
    idx=text_to_token_ids(input_text, tokenizer),
    max_new_tokens=35,
    context_size=BASE_CONFIG["context_length"],
    eos_id=50256,
)
generated_text = token_ids_to_text(token_ids, tokenizer)

# %%
response_text = generated_text[len(input_text):].strip()
print(response_text)
# Out:
# The 'I'may'###
# ######
#
#
# I'mo'
#  'I

# %%
import tiktoken
import math

def generate_text_simple(model, idx,
                         max_new_tokens, context_size): 
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)

        logits = logits[:, -1, :]
        probas = torch.softmax(logits, dim=-1)
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)
        idx = torch.cat((idx, idx_next), dim=1)

    return idx

# %% [markdown]
# fine tuning LLM on instruction data

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch = input_batch.to(device)
    target_batch = target_batch.to(device)      
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(
        logits.flatten(0, 1), target_batch.flatten()
    )
    return loss

def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches



def train_model_simple(model, train_loader, val_loader,
                       optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    for epoch in range(num_epochs):
        model.train()
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            loss.backward()
            optimizer.step()
            tokens_seen += input_batch.numel()
            global_step += 1

            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, "
                      f"Val loss {val_loss:.3f}"
                )

        generate_and_print_sample(
            model, tokenizer, device, start_context
        )
    return train_losses, val_losses, track_tokens_seen



def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(
            train_loader, model, device, num_batches=eval_iter
        )
        val_loss = calc_loss_loader(
            val_loader, model, device, num_batches=eval_iter
        )
        model.train()
        return train_loss, val_loss
    
    
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model = model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
        
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))
    model.train()

# %%
model.to(device)
torch.manual_seed(123)

with torch.no_grad():
    train_loss = calc_loss_loader(
        train_loader, model, device, num_batches=5
    )
    val_loss = calc_loss_loader(
        val_loader, model, device, num_batches=5
)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 6.295484733581543
# Validation loss: 6.269211101531982

# %%
import time

start_time = time.time()
torch.manual_seed(123)
optimizer = torch.optim.AdamW(
    model.parameters(), lr=0.00005, weight_decay=0.1
)
num_epochs = 2

train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context=format_input(val_data[0]), tokenizer=tokenizer
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 6.734, Val loss 6.608
# Ep 1 (Step 000005): Train loss 6.232, Val loss 6.178
# Ep 1 (Step 000010): Train loss 5.453, Val loss 5.366
# Ep 1 (Step 000015): Train loss 5.013, Val loss 4.866
# Ep 1 (Step 000020): Train loss 4.714, Val loss 4.774
# Ep 1 (Step 000025): Train loss 4.639, Val loss 4.485
# Ep 1 (Step 000030): Train loss 3.998, Val loss 4.340
# Ep 1 (Step 000035): Train loss 4.009, Val loss 4.189
# Ep 1 (Step 000040): Train loss 4.124, Val loss 3.864
# Ep 1 (Step 000045): Train loss 3.445, Val loss 3.735
# Ep 1 (Step 000050): Train loss 4.025, Val loss 3.718
# Ep 1 (Step 000055): Train loss 3.369, Val loss 3.666
# Ep 1 (Step 000060): Train loss 3.618, Val loss 3.585
# Ep 1 (Step 000065): Train loss 3.230, Val loss 3.642
# Ep 1 (Step 000070): Train loss 2.931, Val loss 3.391
# Ep 1 (Step 000075): Train loss 3.206, Val loss 3.437
# Ep 1 (Step 000080): Train loss 3.071, Val loss 3.411
# Ep 1 (Step 000085): Train loss 3.162, Val loss 3.392
# Ep 1 (Step 000090): Train loss 3.100, Val loss 3.436
# Ep 1 (Step 000095): Train loss 3.299, Val loss 3.627
# Ep 1 (Step 000100): Train loss 3.150, Val loss 3.593
# Ep 1 (Step 000105): Train loss 3.694, Val loss 3.670
# Ep 1 (Step 000110): Train loss 3.883, Val loss 3.661
# Ep 1 (Step 000115): Train loss 4.159, Val loss 4.262
# Ep 1 (Step 000120): Train loss 4.404, Val loss 4.452
# Ep 1 (Step 000125): Train loss 4.808, Val loss 4.856
# Ep 1 (Step 000130): Train loss 4.237, Val loss 4.355
# Ep 1 (Step 000135): Train loss 4.238, Val loss 4.561
# Ep 1 (Step 000140): Train loss 4.149, Val loss 4.365
# Ep 1 (Step 000145): Train loss 4.538, Val loss 4.749
# Ep 1 (Step 000150): Train loss 3.993, Val loss 4.413
# Ep 1 (Step 000155): Train loss 4.192, Val loss 4.228
# Ep 1 (Step 000160): Train loss 4.074, Val loss 4.232
# Ep 1 (Step 000165): Train loss 4.634, Val loss 4.687
# Ep 1 (Step 000170): Train loss 4.209, Val loss 4.694
# Ep 1 (Step 000175): Train loss 4.733, Val loss 4.869
# Ep 1 (Step 000180): Train loss 5.197, Val loss 6.059
# Ep 1 (Step 000185): Train loss 5.207, Val loss 5.767
# Ep 1 (Step 000190): Train loss 4.394, Val loss 5.183
# Ep 1 (Step 000195): Train loss 4.332, Val loss 4.933
# Ep 1 (Step 000200): Train loss 4.809, Val loss 4.734
# Ep 1 (Step 000205): Train loss 4.355, Val loss 4.533
# Ep 1 (Step 000210): Train loss 4.385, Val loss 4.327
# Ep 1 (Step 000215): Train loss 3.733, Val loss 4.298
# Ep 1 (Step 000220): Train loss 3.341, Val loss 4.139
# Ep 1 (Step 000225): Train loss 3.405, Val loss 4.146
# Ep 1 (Step 000230): Train loss 3.712, Val loss 3.947
# Ep 1 (Step 000235): Train loss 3.629, Val loss 3.895
# Ep 1 (Step 000240): Train loss 3.654, Val loss 3.836
# Ep 1 (Step 000245): Train loss 3.788, Val loss 3.789
# Ep 1 (Step 000250): Train loss 3.502, Val loss 3.733
# Ep 1 (Step 000255): Train loss 3.236, Val loss 3.679
# Ep 1 (Step 000260): Train loss 3.144, Val loss 3.660
# Ep 1 (Step 000265): Train loss 3.208, Val loss 3.618
# Ep 1 (Step 000270): Train loss 3.179, Val loss 3.604
# Ep 1 (Step 000275): Train loss 3.240, Val loss 3.559
# Ep 1 (Step 000280): Train loss 3.263, Val loss 3.549
# Ep 1 (Step 000285): Train loss 3.084, Val loss 3.504
# Ep 1 (Step 000290): Train loss 3.063, Val loss 3.496
# Ep 1 (Step 000295): Train loss 3.213, Val loss 3.442
# Ep 1 (Step 000300): Train loss 2.816, Val loss 3.446
# Ep 1 (Step 000305): Train loss 3.004, Val loss 3.427
# Ep 1 (Step 000310): Train loss 2.560, Val loss 3.405
# Ep 1 (Step 000315): Train loss 2.833, Val loss 3.383
# Ep 1 (Step 000320): Train loss 2.967, Val loss 3.370
# Ep 1 (Step 000325): Train loss 2.930, Val loss 3.341
# Ep 1 (Step 000330): Train loss 2.586, Val loss 3.314
# Ep 1 (Step 000335): Train loss 2.773, Val loss 3.319
# Ep 1 (Step 000340): Train loss 3.478, Val loss 3.296
# Ep 1 (Step 000345): Train loss 2.919, Val loss 3.322
# Ep 1 (Step 000350): Train loss 2.631, Val loss 3.280
# Ep 1 (Step 000355): Train loss 2.662, Val loss 3.282
# Ep 1 (Step 000360): Train loss 3.132, Val loss 3.270
# Ep 1 (Step 000365): Train loss 2.660, Val loss 3.287
# Ep 1 (Step 000370): Train loss 3.019, Val loss 3.301
# Ep 1 (Step 000375): Train loss 2.909, Val loss 3.280
# Ep 1 (Step 000380): Train loss 2.802, Val loss 3.234
# Ep 1 (Step 000385): Train loss 3.075, Val loss 3.250
# Ep 1 (Step 000390): Train loss 3.182, Val loss 3.277
# Ep 1 (Step 000395): Train loss 3.182, Val loss 3.249
# Ep 1 (Step 000400): Train loss 2.745, Val loss 3.266
# Ep 1 (Step 000405): Train loss 2.550, Val loss 3.248
# Ep 1 (Step 000410): Train loss 2.825, Val loss 3.276
# Ep 1 (Step 000415): Train loss 3.262, Val loss 3.237
# Ep 1 (Step 000420): Train loss 2.736, Val loss 3.262
# Ep 1 (Step 000425): Train loss 3.036, Val loss 3.511
# Ep 1 (Step 000430): Train loss 2.763, Val loss 3.519
# Ep 1 (Step 000435): Train loss 3.064, Val loss 3.594
# Ep 1 (Step 000440): Train loss 2.815, Val loss 3.411
# Ep 1 (Step 000445): Train loss 3.078, Val loss 3.414
# Ep 1 (Step 000450): Train loss 3.016, Val loss 3.245
# Ep 1 (Step 000455): Train loss 2.748, Val loss 3.347
# Ep 1 (Step 000460): Train loss 2.852, Val loss 3.344
# Ep 1 (Step 000465): Train loss 2.688, Val loss 3.322
# Below is an instruction that describe a task. Write a response that appropriately completes the request  ### Instruction: Convert the active sentence to passive: 'The chef cooks the meal every day.' the sentence. ### Response: ### Response: ### Response:  . .        ### Response:  ### Response. ### Response. ### Response.   ### Response:
# Ep 2 (Step 000470): Train loss 3.117, Val loss 3.280
# Ep 2 (Step 000475): Train loss 2.931, Val loss 3.247
# Ep 2 (Step 000480): Train loss 2.870, Val loss 3.245
# Ep 2 (Step 000485): Train loss 2.652, Val loss 3.198
# Ep 2 (Step 000490): Train loss 2.683, Val loss 3.201
# Ep 2 (Step 000495): Train loss 2.885, Val loss 3.189
# Ep 2 (Step 000500): Train loss 2.458, Val loss 3.154
# Ep 2 (Step 000505): Train loss 2.882, Val loss 3.151
# Ep 2 (Step 000510): Train loss 2.606, Val loss 3.135
# Ep 2 (Step 000515): Train loss 2.441, Val loss 3.103
# Ep 2 (Step 000520): Train loss 2.884, Val loss 3.114
# Ep 2 (Step 000525): Train loss 2.749, Val loss 3.056
# Ep 2 (Step 000530): Train loss 2.693, Val loss 3.101
# Ep 2 (Step 000535): Train loss 2.899, Val loss 3.080
# Ep 2 (Step 000540): Train loss 2.774, Val loss 3.107
# Ep 2 (Step 000545): Train loss 2.867, Val loss 3.089
# Ep 2 (Step 000550): Train loss 2.808, Val loss 3.098
# Ep 2 (Step 000555): Train loss 2.904, Val loss 3.115
# Ep 2 (Step 000560): Train loss 2.814, Val loss 3.121
# Ep 2 (Step 000565): Train loss 2.920, Val loss 3.145
# Ep 2 (Step 000570): Train loss 2.598, Val loss 3.141
# Ep 2 (Step 000575): Train loss 2.840, Val loss 3.120
# Ep 2 (Step 000580): Train loss 2.718, Val loss 3.118
# Ep 2 (Step 000585): Train loss 2.928, Val loss 3.066
# Ep 2 (Step 000590): Train loss 3.282, Val loss 3.096
# Ep 2 (Step 000595): Train loss 2.449, Val loss 3.113
# Ep 2 (Step 000600): Train loss 2.585, Val loss 3.077
# Ep 2 (Step 000605): Train loss 2.845, Val loss 3.139
# Ep 2 (Step 000610): Train loss 3.044, Val loss 3.214
# Ep 2 (Step 000615): Train loss 2.167, Val loss 3.080
# Ep 2 (Step 000620): Train loss 2.887, Val loss 3.135
# Ep 2 (Step 000625): Train loss 2.669, Val loss 3.191
# Ep 2 (Step 000630): Train loss 2.891, Val loss 3.168
# Ep 2 (Step 000635): Train loss 2.766, Val loss 3.168
# Ep 2 (Step 000640): Train loss 2.449, Val loss 3.097
# Ep 2 (Step 000645): Train loss 2.631, Val loss 3.083
# Ep 2 (Step 000650): Train loss 2.709, Val loss 3.065
# Ep 2 (Step 000655): Train loss 2.733, Val loss 3.053
# Ep 2 (Step 000660): Train loss 2.333, Val loss 3.137
# Ep 2 (Step 000665): Train loss 3.331, Val loss 3.115
# Ep 2 (Step 000670): Train loss 2.897, Val loss 3.173
# Ep 2 (Step 000675): Train loss 2.864, Val loss 3.160
# Ep 2 (Step 000680): Train loss 2.513, Val loss 3.161
# Ep 2 (Step 000685): Train loss 2.438, Val loss 3.097
# Ep 2 (Step 000690): Train loss 2.286, Val loss 3.071

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(
        epochs_seen, val_losses, linestyle="-.", label="Validation loss"
    )
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax2 = ax1.twiny()
    ax2.plot(tokens_seen, train_losses, alpha=0)
    ax2.set_xlabel("Tokens seen")
    fig.tight_layout()
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)

# %%
torch.manual_seed(123)

for entry in test_data[:3]:
    input_text = format_input(entry)
    token_ids = generate(
        model=model,
        idx=text_to_token_ids(input_text, tokenizer).to(device),
        max_new_tokens=256,
        context_size=BASE_CONFIG["context_length"],
        eos_id=50256
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)

    response_text = (
        generated_text[len(input_text):]
        .replace("### Response:", "")
        .strip()
    )
    print(input_text)
    print(f"\nCorrect response:\n>> {entry['output']}")
    print(f"\nModel response:\n>> {response_text.strip()}")
    print("-------------------------------------")

# %%
# Generating Test set responses

from tqdm import tqdm

for i, entry in tqdm(enumerate(test_data), total=len(test_data)):
    input_text = format_input(entry)

    token_ids = generate(
        model=model,
        idx=text_to_token_ids(input_text, tokenizer).to(device),
        max_new_tokens=256,
        context_size=BASE_CONFIG["context_length"],
        eos_id=50256
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)

    response_text = (
        generated_text[len(input_text):]
        .replace("### Response:", "")
        .strip()
    )
    test_data[i]["model_response"] = response_text

with open("instruction-data-with-response.json", "w") as file:
    json.dump(test_data, file, indent=4)

# %%
print(test_data[0])

# %%
import re

file_name = f"{re.sub(r'[ ()]', '', CHOOSE_MODEL) }-sft.pth"
torch.save(model.state_dict(), file_name)
print(f"Model saved as {file_name}")

# %% [markdown]
# Evaluating the fine-tuned LLM
